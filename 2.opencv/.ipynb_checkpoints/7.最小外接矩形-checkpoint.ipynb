# %%
import cv2
from skimage import morphology
import matplotlib.pyplot as plt
import numpy as np

# %%
img_mask = cv2.imread('./image_file/mask/pointer_msk.jpg',0)  # 0表示以灰度图的方式读取图片
plt.imshow(img_mask, cmap='gray')

# %%
contours, hierarchy = cv2.findContours(img_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
min_rect = cv2.minAreaRect(contours[0])

# %%
min_rect  # 矩形中心点坐标，矩形的宽和高，相对水平方向的旋转角度
# Out:
# ((281.896240234375, 284.11322021484375),
#  (209.72035217285156, 18.121706008911133),
#  42.51044845581055)
